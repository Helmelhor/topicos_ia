# %%
#projeto tópicos teste 1

# %%
import gym
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from gym.wrappers import GrayScaleObservation, ResizeObservation
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback

# Função para criar o ambiente do jogo, agora com pré-processamento
def make_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')
    # Adiciona os wrappers para otimizar a imagem
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    return env

# Cria 4 ambientes de jogo para treinar em paralelo
vec_env = make_vec_env(make_env, n_envs=4, vec_env_cls=DummyVecEnv)

# Agrupa 4 frames de tela para dar ao agente a noção de movimento
env = VecFrameStack(vec_env, n_stack=4)

# Configura o salvamento automático do modelo a cada 500.000 passos
checkpoint_callback = CheckpointCallback(save_freq=50000, save_path='./train/', name_prefix='mario_model')

# Instancia o modelo PPO
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log="./mario_tensorboard/")

# Inicia o treinamento (reduzimos para 1 milhão para um primeiro teste)
model.learn(total_timesteps=1000000, callback=checkpoint_callback)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./mario_tensorboard/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 298  |
# |    iterations      | 1    |
# |    time_elapsed    | 27   |
# |    total_timesteps | 8192 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 2          |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01688309 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.93      |
# |    explained_variance   | -5.21e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.06       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.00821    |
# |    value_loss           | 18         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 3           |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013133438 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -0.0354     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 0.292       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 4           |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012375404 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0617      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00113     |
# |    value_loss           | 1.12        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 5           |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009174566 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.396       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00643     |
# |    value_loss           | 12.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 6           |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013546889 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0138      |
# |    value_loss           | 4.03        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 7           |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017761668 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00254     |
# |    value_loss           | 7.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 630         |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 8           |
# |    time_elapsed         | 713         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018081427 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00531     |
# |    value_loss           | 1.87        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | 630        |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 9          |
# |    time_elapsed         | 811        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01023139 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.79      |
# |    explained_variance   | 0.733      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.531      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.00392    |
# |    value_loss           | 14.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 630         |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 10          |
# |    time_elapsed         | 908         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010925424 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.055       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0141      |
# |    value_loss           | 1.78        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | 630        |
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 11         |
# |    time_elapsed         | 1003       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00893835 |
# |    clip_fraction        | 0.0767     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | 0.62       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.083      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00368   |
# |    value_loss           | 0.114      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+04       |
# |    ep_rew_mean          | 627         |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 12          |
# |    time_elapsed         | 1100        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008590506 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00186     |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+04       |
# |    ep_rew_mean          | 627         |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 13          |
# |    time_elapsed         | 1198        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008696438 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.94        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00348     |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+04       |
# |    ep_rew_mean          | 627         |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 14          |
# |    time_elapsed         | 1295        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012782344 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0042      |
# |    value_loss           | 11.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2e+04      |
# |    ep_rew_mean          | 627        |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 15         |
# |    time_elapsed         | 1394       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.06540356 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.74      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.592      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0054    |
# |    value_loss           | 3.06       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+04    |
# |    ep_rew_mean          | 649         |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 16          |
# |    time_elapsed         | 1490        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.018810295 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00307     |
# |    value_loss           | 0.562       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.75e+04   |
# |    ep_rew_mean          | 742        |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 17         |
# |    time_elapsed         | 1585       |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.00832121 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.792      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.14       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.000372  |
# |    value_loss           | 21.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.75e+04    |
# |    ep_rew_mean          | 742         |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 18          |
# |    time_elapsed         | 1680        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.009938428 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.563       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000184   |
# |    value_loss           | 15.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.75e+04    |
# |    ep_rew_mean          | 742         |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 19          |
# |    time_elapsed         | 1775        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.012717498 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.49        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00445     |
# |    value_loss           | 15.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.85e+04  |
# |    ep_rew_mean          | 770       |
# | time/                   |           |
# |    fps                  | 87        |
# |    iterations           | 20        |
# |    time_elapsed         | 1872      |
# |    total_timesteps      | 163840    |
# | train/                  |           |
# |    approx_kl            | 0.0190938 |
# |    clip_fraction        | 0.17      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.68     |
# |    explained_variance   | 0.933     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.332     |
# |    n_updates            | 190       |
# |    policy_gradient_loss | 0.00257   |
# |    value_loss           | 1.85      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.85e+04    |
# |    ep_rew_mean          | 770         |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 21          |
# |    time_elapsed         | 1969        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.012748878 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00452     |
# |    value_loss           | 26.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+04    |
# |    ep_rew_mean          | 1.07e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 22          |
# |    time_elapsed         | 2067        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.017429534 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00454     |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+04    |
# |    ep_rew_mean          | 1.07e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 23          |
# |    time_elapsed         | 2160        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.011241128 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00782     |
# |    value_loss           | 34.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.69e+04    |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 24          |
# |    time_elapsed         | 2252        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.012642934 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0133      |
# |    value_loss           | 3.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+04    |
# |    ep_rew_mean          | 1.14e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 25          |
# |    time_elapsed         | 2350        |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.018570611 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 14.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+04    |
# |    ep_rew_mean          | 1.14e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 26          |
# |    time_elapsed         | 2446        |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.023680417 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.22        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00371     |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+04    |
# |    ep_rew_mean          | 1.14e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 27          |
# |    time_elapsed         | 2540        |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.017347477 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00284     |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.66e+04    |
# |    ep_rew_mean          | 1.11e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 28          |
# |    time_elapsed         | 2636        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.109529786 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.067       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0311      |
# |    value_loss           | 1.47        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.66e+04   |
# |    ep_rew_mean          | 1.11e+03   |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 29         |
# |    time_elapsed         | 2729       |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.07538256 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.63       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0166    |
# |    value_loss           | 10.1       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.66e+04  |
# |    ep_rew_mean          | 1.11e+03  |
# | time/                   |           |
# |    fps                  | 87        |
# |    iterations           | 30        |
# |    time_elapsed         | 2823      |
# |    total_timesteps      | 245760    |
# | train/                  |           |
# |    approx_kl            | 0.0411966 |
# |    clip_fraction        | 0.146     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.12     |
# |    explained_variance   | 0.899     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.22      |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.00272  |
# |    value_loss           | 6.84      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.66e+04    |
# |    ep_rew_mean          | 1.11e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 31          |
# |    time_elapsed         | 2918        |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.016582662 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.874       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00102     |
# |    value_loss           | 5.37        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.67e+04   |
# |    ep_rew_mean          | 1.06e+03   |
# | time/                   |            |
# |    fps                  | 87         |
# |    iterations           | 32         |
# |    time_elapsed         | 3011       |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.04499802 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.991     |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.891      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0116     |
# |    value_loss           | 2.93       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+04    |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 33          |
# |    time_elapsed         | 3104        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.014458165 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00147     |
# |    value_loss           | 6.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+04    |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 34          |
# |    time_elapsed         | 3204        |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.014012037 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 9.97e-05    |
# |    value_loss           | 7.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+04    |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 35          |
# |    time_elapsed         | 3299        |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.044856794 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.11        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 5.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+04    |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 36          |
# |    time_elapsed         | 3394        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.008131988 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00594     |
# |    value_loss           | 1.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.65e+04    |
# |    ep_rew_mean          | 977         |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 37          |
# |    time_elapsed         | 3489        |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.012313597 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00202     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+04    |
# |    ep_rew_mean          | 948         |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 38          |
# |    time_elapsed         | 3583        |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.011362534 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+04    |
# |    ep_rew_mean          | 948         |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 39          |
# |    time_elapsed         | 3676        |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.023940835 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.25        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00286     |
# |    value_loss           | 7.24        |
# -----------------------------------------

# %%
import gym
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from gym.wrappers import GrayScaleObservation, ResizeObservation
from stable_baselines3 import PPO

# É crucial usar EXATAMENTE a mesma função 'make_env' do treinamento
# para que o modelo entenda a "visão" do jogo.
def make_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    return env

# Crie o ambiente (apenas um, não precisa de paralelismo para teste) 
env = make_env()

# Carregue o modelo treinado. 
# ATENÇÃO: Altere o nome do arquivo para o modelo que você quer testar! 
# Por exemplo, mario_model_500000_steps.zip ou o de 1M.
model = PPO.load('./train/mario_model_1000000_steps.zip')

# Inicia a simulação
obs = env.reset()
done = False
while not done:
    # O modelo PPO usa o estado para prever a próxima ação 
    action, _states = model.predict(obs, deterministic=True)
    
    # A ação é executada no ambiente [cite: 70]
    obs, rewards, done, info = env.step(action)
    
    # Renderiza o frame do jogo na tela para você assistir 
    env.render()

# Fecha o ambiente ao final
env.close()
